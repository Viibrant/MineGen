# %% [markdown]
# # Setup

# %%
# %pip install positional-encodings[pytorch]

# %%
import pathlib
import os

if os.getcwd().split("\\")[-1] == "notebooks":
    os.chdir(pathlib.Path().absolute() / "..")
os.getcwd()

# %%
import math
import matplotlib.pyplot as plt
import lightning.pytorch as pl
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from einops import rearrange
from einops.layers.torch import Rearrange
from lightning import LightningModule
from pytorch_lightning.loggers import WandbLogger
from torch import nn
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import DataLoader
from tqdm import tqdm

import wandb
from data import build_dataset
from data.datasets.schematics import SchematicDataModule
from layers import NestedTransformer, TransformerLayer
from nbtschematic import SchematicFile
from sklearn.utils.class_weight import compute_class_weight

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %% [markdown]
# # Modelling

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv3d(
            in_channels, in_channels * 2, kernel_size=3, stride=1, padding=1
        )
        self.norm1 = nn.BatchNorm3d(in_channels * 2)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv3d(
            in_channels * 2, in_channels, kernel_size=3, stride=1, padding=1
        )
        self.norm2 = nn.BatchNorm3d(in_channels)

    def forward(self, x):
        residual = x

        out = self.conv1(x)
        out = self.norm1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.norm2(out)

        out += residual
        out = self.relu(out)

        return out

# %%
def plot_blockid_distribution(b_id, c):
    """
    Plot distribution of block IDs in generated schematics.
    """

    blockid_counts = torch.zeros(512, dtype=torch.int64, device=device)
    blockid_counts.scatter_add_(0, b_id.type(torch.int64), c)

    # Get count and percentage of air (block ID 0)
    air_count = blockid_counts[0].item()
    total_count = blockid_counts.sum().item()
    air_percentage = 100 * air_count / total_count

    # Remove block ID 0 from data
    non_air_indices = b_id != 0
    b_id_non_air = b_id[non_air_indices].cpu()
    c_non_air = c[non_air_indices].cpu()

    # Create pandas series without block ID 0
    blockid_counts_series = pd.Series(c_non_air.numpy(), index=b_id_non_air.numpy())

    # Create plot
    plt.figure(figsize=(12, 5))
    g = sns.barplot(x=blockid_counts_series.index, y=blockid_counts_series.values)
    g.set_title("Distribution of Block IDs in Generated Schematics (excluding Air)")
    g.set_xlabel("Block ID")
    g.set_ylabel("Count")
    _ = g.set_xticklabels(g.get_xticklabels(), rotation=90)

    # Add labels above each bar
    for i, v in enumerate(blockid_counts_series.values):
        g.text(i, v + 25, str(v), color="black", ha="center")

    # Add note about air
    note = f"Note: Air (Block ID 0) was excluded from this plot.\nThere were {air_count} Air blocks, comprising {air_percentage:.2f}% of total blocks."
    plt.figtext(0.5, -0.1, note, wrap=True, horizontalalignment="center", fontsize=12)

    return g

# %% [markdown]
# ## Smaller schematic volumes

# %%
#!TODO: Reporting of block distributinon
# - [ ] Plot distribution of block IDs in generated schematics

# %%
class lolModel(LightningModule):
    """Takes a schematic, partitions it into patches, 
    and applies a NestedTransformer to each patch.
    """

    def __init__(self, in_size=16, C_embed=16, num_cat=20, num_heads=8, num_layers=16, patch_size=8) -> None:
        super().__init__()

        self.patch_size = patch_size
        self.C_embed = C_embed
        self.num_cat = num_cat

        num_hierarchies = int(math.log2(in_size)) 

        # Initialize the hierarchical transformers for downscaling
        self.downscale_hierarchies = nn.ModuleList([
            NestedTransformer(self.patch_size, self.C_embed*2**i, num_heads, num_layers, in_channels=int(self.C_embed*2**(i-1)) if i != 0 else None) 
            for i in range(num_hierarchies)
        ])

        self.conv = nn.LazyConv3d(512, 1)

        # Initialize the upsampling layers for each hierarchy
        self.upscale_hierarchies = nn.ModuleList([
            nn.LazyConvTranspose3d(int(self.C_embed*2**(i-1)) if i != 1 else self.C_embed, 2, stride=2) 
            for i in range(num_hierarchies-1, -1, -1)
        ])
        
        self.conv_upscale = nn.LazyConv3d(self.C_embed, 1)
        
        self.embedding = nn.Sequential(
            nn.Embedding(768, self.C_embed, scale_grad_by_freq=True, padding_idx=0),
            Rearrange("b d h w c -> b c d h w")
        )
        
        self.classifier = nn.Sequential(
            nn.Conv3d(512, 256, 3, stride=2),
            nn.ReLU(),
            nn.Conv3d(256, 128, 3, stride=2),
            nn.ReLU(),
            nn.Conv3d(128, 64, 3, stride=2),
            nn.ReLU(),
            nn.Flatten(),
            # clf to num_cat classes
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, num_cat),
        )
        
        self.res_blocks_pre = nn.ModuleList([ResidualBlock(self.C_embed*2**i) for i in range(num_hierarchies-1, -1, -1)])
        self.res_blocks_post = nn.ModuleList([ResidualBlock(self.C_embed*2**i) for i in range(num_hierarchies-1, -1, -1)])
        
        self.save_hyperparameters()
        

    def forward(self, x):
        seq = self.embedding(x.abs().long())

        # Downscale through the hierarchies and store intermediate representations
        downscale_outputs = []
        for downscale in self.downscale_hierarchies:
            seq = downscale(seq)
            downscale_outputs.append(seq)
            
        # Upscale through the hierarchies and add in skip connections from downscale path
        for upscale, down_out, res_pre, res_post in zip(self.upscale_hierarchies, reversed(downscale_outputs), self.res_blocks_pre, self.res_blocks_post):
            seq = res_pre(down_out) + seq   # Apply ResBlock before addition
            seq = res_post(seq)             # Apply ResBlock after addition
            seq = upscale(seq)

        seq = self.conv_upscale(seq)
        seq = self.conv(seq)
        
        
        cat = self.classifier(seq)
        
        return seq, cat
    
    def predict_step(self, batch, _):
        return self(batch)


    def training_step(self, batch, _):
        x, y = batch
        logits, cat = self.forward(x)
        
        recon_loss = F.cross_entropy(logits, x.abs().long())
        cat_loss = F.binary_cross_entropy_with_logits(cat, y)
        
        self.log("train/recon_loss", recon_loss)
        self.log("train/cat_loss", cat_loss)
        
        loss = recon_loss + cat_loss
        
        return loss
    

    def validation_step(self, batch, _):
        x, y = batch
        logits, cat = self.forward(x)
        
        recon_loss = F.cross_entropy(logits, x.abs().long())
        cat_loss = F.binary_cross_entropy_with_logits(cat, y)
        
        
        
        self.log("val/recon_loss", recon_loss)
        self.log("val/cat_loss", cat_loss)
        # self.log("val/block_id_distribution", block_id_distribution)
        
        
        loss = recon_loss + cat_loss
        
        return loss
        
    def configure_optimizers(self):
        optimiser = torch.optim.Adam(self.parameters(), lr=1e-2, weight_decay=1e-5, amsgrad=True)
        return optimiser

# %%
model = lolModel.load_from_checkpoint(
    "MineGen/wzqgpvog/checkpoints/epoch=66-step=4757.ckpt"
)

# %%
model = lolModel.load_from_checkpoint(
    "MineGen/cnm2znk0/checkpoints/epoch=99-step=3600.ckpt"
)

# %%
x.unique(return_counts=True)

# %%
y.argmax( dim=1)

# %%
cat_names = dataset.train_dataloader().dataset.dataset.enc.categories_[0]
cat_names

# %%
def to_schematic(obj: np.ndarray, shape=(16, 16, 16)):
    sf = SchematicFile(shape)
    sf.blocks = obj
    return sf

# %%
model = lolModel(num_heads=NUM_HEADS, num_layers=NUM_LAYERS)
model.load_state_dict(torch.load("model.pt"))

# %%
x, y = next(_iter)

# %%
[cat_names[i] for i in y.argmax(dim=1)]

# %%
x_hat, y_hat = model(x)

# %%
x_hat.argmax(dim=1).unique(return_counts=True)

# %%
y_hat

# %%
y_hat.argmax(dim=1).unique(return_counts=True)

# %%
y.argmax(dim=1)

# %%
# function to write predicted schematics logits to files
def write_schematics(model, x, y, cat_names, path=pathlib.Path("generatedlol/")):
    path.mkdir(parents=True, exist_ok=True)
    x_hat, y_hat = model(x)
    print(x_hat.argmax(dim=1).unique(return_counts=True))
    for i, _x in enumerate(x_hat):
        gen_name = f"{i}_{cat_names[y_hat[i].argmax(dim=0)]}.schematic"
        real_name = f"{i}_{cat_names[y[i].argmax(dim=0)]}.schematic"
        
        schematic = _x.argmax(dim=0).numpy()
        sf_gen: SchematicFile = to_schematic(schematic)
        sf_gen.save(path / f"gen_{gen_name}")

        sf_real: SchematicFile = to_schematic(x[i].numpy())
        sf_real.save(path / f"real_{real_name}")

    print(x_hat.argmax(dim=1).unique(return_counts=True))


write_schematics(model, x, y, cat_names)

# %% [markdown]
# record hyperparameters and results - potential local optima

# %% [markdown]
# ## Training

# %%
BATCH_SIZE = 64
NUM_HEADS = 8
NUM_LAYERS = 12
PATCH_SIZE = 2
C_EMBED = 64

# %%
wandb_logger = WandbLogger(project="MineGen")
wandb_logger.experiment.config["batch_size"] = BATCH_SIZE
wandb_logger.experiment.config["num_heads"] = NUM_HEADS
wandb_logger.experiment.config["num_layers"] = NUM_LAYERS

# %%
dataset = SchematicDataModule(num_workers=12, batch_size=BATCH_SIZE)
model = lolModel(num_heads=NUM_HEADS, num_layers=NUM_LAYERS, patch_size=2)
trainer = pl.Trainer(
    max_epochs=500, log_every_n_steps=1, logger=wandb_logger, num_sanity_val_steps=0
)
trainer.fit(model, dataset)
wandb.finish()

# %%
from nbtschematic import SchematicFile

# %%
dataset = SchematicDataModule(num_workers=12, batch_size=BATCH_SIZE)
dataset.setup()

# %%
y_val = dataset.train_dataloader().dataset.dataset.metadata["Category"].values
# convert y_val to integer labels
y_val = dataset.train_dataloader().dataset.dataset.enc.transform(y_val.reshape(-1, 1)).toarray().argmax(axis=1)
y_val = torch.tensor(y_val)
y_val.unique(return_counts=True)

# %%
_iter = iter(dataset.train_dataloader())

# %%
x, y = next(_iter)
x

# %%
compute_class_weight("balanced", classes=y

# %%
x = x.to(model.device)

# %%
x_hat, y_hat = model(x)

# %%
x_hat.argmax(dim=1)[1].unique(return_counts=True)

# %%
sf = SchematicFile(shape=(16, 16, 16))
sf.blocks = x_hat[2].cpu().numpy()
sf.save("_________OG.schematic")

# %%
y_hat.view(-1, 20).shape

# %%
x[22]

# %%
dataset.train_dataset.dataset.enc.categories_[0]
